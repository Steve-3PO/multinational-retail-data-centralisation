# %% [markdown]
# NOTE: This is a trial file which i used to test the cleaning i did in pandas before taking across to data_cleaning.py

# %%
import pandas as pd
import yaml
import tabula
import re
import numpy as np
import boto3
from sqlalchemy import create_engine, inspect
from database_utils import DatabaseConnector
from data_extraction import DataExtractor
from data_cleaning import DataCleaning

# %%
db = DatabaseConnector() 

users = DataExtractor.read_rds_table(db, 'legacy_users')
# Out:
# ['legacy_store_details', 'legacy_users', 'orders_table']

# %% [markdown]
# First Check and Convert All types

# %%
users.dtypes
# Out:
# index             int64
# first_name       object
# last_name        object
# date_of_birth    object
# company          object
# email_address    object
# address          object
# country          object
# country_code     object
# phone_number     object
# join_date        object
# user_uuid        object
# dtype: object

# %%
users['first_name'] = users['first_name'].astype('string')
users['last_name'] = users['last_name'].astype('string')
users['company'] = users['company'].astype('string')
users['email_address'] = users['email_address'].astype('string')
users['address'] = users['address'].astype('string')
users['country'] = users['country'].astype('category')
users['country_code'] = users['country_code'].astype('category')
users['phone_number'] = users['phone_number'].astype('string')
users['user_uuid'] = users['user_uuid'].astype('string')

# %% [markdown]
# Check again to make sure changes occurred

# %%
users.dtypes
# Out:
# index               int64
# first_name         string
# last_name          string
# date_of_birth      object
# company            string
# email_address      string
# address            string
# country          category
# country_code     category
# phone_number       string
# join_date          object
# user_uuid          string
# dtype: object

# %% [markdown]
# set index as index, as there are two columns for this usage

# %%
users = users.set_index('index')

# %% [markdown]
# check the categorical country code variables and remove all wrong values, convert any mistakes

# %%
users['country_code'].value_counts()
# Out:
# GB            9365
# DE            4708
# US            1205
# NULL            21
# GGB              6
# PG8MOC0UZI       1
# XKI9UXSCZ1       1
# VSM4IZ4EL3       1
# RVRFD92E48       1
# QVUW9JSKY3       1
# QREF9WLI2A       1
# 0CU6LW3NKB       1
# OS2P9CMHR6       1
# 44YAIDY048       1
# NTCGYW8LVC       1
# LZGTB0T5Z7       1
# IM8MN1L9MJ       1
# FB13AKRI21       1
# 5D74J6FPFJ       1
# XPVCZE2L8B       1
# Name: country_code, dtype: int64

# %%
users = users[users['country_code'].str.len() < 4]
users['country_code'] = users['country_code'].replace('GGB', 'GB')

# %% [markdown]
# check country code again

# %%
users['country_code'].value_counts()
# Out:
# GB            9371
# DE            4708
# US            1205
# 0CU6LW3NKB       0
# PG8MOC0UZI       0
# XKI9UXSCZ1       0
# VSM4IZ4EL3       0
# RVRFD92E48       0
# QVUW9JSKY3       0
# QREF9WLI2A       0
# NULL             0
# OS2P9CMHR6       0
# 44YAIDY048       0
# NTCGYW8LVC       0
# LZGTB0T5Z7       0
# IM8MN1L9MJ       0
# FB13AKRI21       0
# 5D74J6FPFJ       0
# XPVCZE2L8B       0
# Name: country_code, dtype: int64

# %% [markdown]
# standardise the phone numbers and remove all special characters

# %%
users['phone_number']
# Out:
# index
# 0         +49(0) 047905356
# 1          (0161) 496 0674
# 2        +44(0)121 4960340
# 3          (0306) 999 0871
# 4            0121 496 0225
#                ...
# 14913      +44(0)292018946
# 14994     +44(0)1144960977
# 15012          02984 08192
# 15269         239.711.3836
# 1249      +44(0)1314960870
# Name: phone_number, Length: 15284, dtype: string

# %%
def standardise_phone_number(phone_number):
    phone_number = phone_number.replace(" ", "")
    phone_number = phone_number.replace("(", "")
    phone_number = phone_number.replace(")", "")
    phone_number = phone_number.replace(".", "")
    phone_number = phone_number.replace("-", "")
    phone_number = phone_number.replace("x", "")
    phone_number = list(phone_number)
    if phone_number[0] == '+':
        phone_number = phone_number[3:]
    phone_number = ''.join(phone_number)
    return phone_number

users['phone_number'] = users['phone_number'].apply(standardise_phone_number)
users['phone_number'] = users['phone_number'].astype('string')
users['phone_number']
# Out:
# index
# 0         0047905356
# 1        01614960674
# 2        01214960340
# 3        03069990871
# 4        01214960225
#             ...
# 14913     0292018946
# 14994    01144960977
# 15012     0298408192
# 15269     2397113836
# 1249     01314960870
# Name: phone_number, Length: 15284, dtype: string

# %% [markdown]
# remove convert like "1968 October 16" and convert date_of_birth/join_date to a datetime variable

# %%
users["date_of_birth"].str.len().max()
# Out:
# 16

# %%
def standardise_date(date):
    
    if len(date) == 10:
        return date
    
    months_dict = {'January':'01', 'February':'02', 'March':'03', 'April':'04', 
                   'May':'05', 'June':'06', 'July':'07', 'August':'08',
                   'September':'09', 'October':'10', 'November':'11', 'December':'12'}
    
    split_date = date.split(" ")
    day = split_date[-1]
    if split_date[0][0].isalpha():
        month = split_date[0]
        year = split_date[1]
    else:
        month = split_date[1]
        year = split_date[0]
    month = months_dict[month]
    # print(day)
    # print(month)
    # print(year)
    return f"{year}-{month}-{day}"

# %%
users['date_of_birth'] = users['date_of_birth'].apply(standardise_date)

# %%
users["date_of_birth"] = pd.to_datetime(users["date_of_birth"], format="%Y-%m-%d")
users["date_of_birth"]
# Out:
# index
# 0       1990-09-30
# 1       1940-12-01
# 2       1995-08-02
# 3       1972-09-23
# 4       1952-12-20
#            ...
# 14913   1943-08-09
# 14994   1948-08-20
# 15012   1940-10-09
# 15269   1952-06-04
# 1249    1994-03-27
# Name: date_of_birth, Length: 15284, dtype: datetime64[ns]

# %%
users["join_date"].str.len().max()
# Out:
# 17

# %%
users['join_date'] = users['join_date'].apply(standardise_date)

# %%
users["join_date"] = pd.to_datetime(users["join_date"], format="%Y-%m-%d")
users["join_date"]
# Out:
# index
# 0       2018-10-10
# 1       2001-12-20
# 2       2016-12-16
# 3       2004-02-23
# 4       2006-09-01
#            ...
# 14913   2016-04-15
# 14994   2020-07-20
# 15012   2021-03-07
# 15269   2011-01-03
# 1249    2015-08-28
# Name: join_date, Length: 15284, dtype: datetime64[ns]

# %% [markdown]
# check and remove users with join dates before their birth dates

# %%
users[users["join_date"] < users["date_of_birth"]].info
# Out:
# <bound method DataFrame.info of       first_name  last_name date_of_birth                          company  \
# index
# 39          Paul   Misicher    2006-08-24                             Kuhl
# 64         Tracy     Turner    2003-11-05        Higgins, Graham and Singh
# 100      William       Wood    1994-05-08      Barker, Patel and Stevenson
# 102         Alan       Hall    2000-03-07  Richardson, Hayward and Farrell
# 127        Wendy      Burke    2005-01-25                   Nixon and Sons
# ...          ...        ...           ...                              ...
# 15286     Thomas      Begum    1996-12-16     Phillips, Chandler and Evans
# 15287      Julie      Lewis    2001-02-20                   Smith and Sons
# 15314   Marliese  Holzapfel    2004-01-11                          Ruppert
# 10454    Stephen   Williams    2005-05-06        Lewis, Fletcher and Allan
# 12523    Stephen   Alvarado    2006-07-27                    Wallace-Smith
#
#                          email_address  \
# index
# 39                  tlangern@ebert.org
# 64     marymartin@barnes-brennan.co.uk
# 100        iwarren@andrews-simmons.com
# 102                abbie13@oconnor.com
# 127              marcusrowe@clarke.biz
# ...                                ...
# 15286    mohamed18@hooper-harrison.com
# 15287             iainharper@green.com
# 15314               fradisch@atzler.de
# 10454             s.williams@smith.com
# 12523             s.alvarado@smith.com
#
#                                              address         country  \
# index
# 39      Aleksandra-Schlosser-Gasse 0
# 97750 Neuruppin         Germany
# 64      Flat 74
# Simon hill
# Lake Chelseaport
# CH5N 9AX  United Kingdom
# 100                3 Hilary green
# Murphyview
# W7G 8NT  United Kingdom
# 102               80 Bell haven
# West Louise
# DN3H 1HU  United Kingdom
# 127     821 Marshall extension
# North Graham
# WD97 2PT  United Kingdom
# ...                                              ...             ...
# 15286               70 Barry ford
# East Marion
# N1 1RW  United Kingdom
# 15287   Studio 99
# Gemma parkway
# Clarkeville
# HP1A 5RU  United Kingdom
# 15314     Martin-Ditschlerin-Straße 96
# 21378 Hünfeld         Germany
# 10454  Flat 80
# Tomlinson mission
# Port Eileen
# G13 3NS  United Kingdom
# 12523      9197 Smith Island
# Port Benjamin, ND 32656   United States
#
#       country_code      phone_number  join_date  \
# index
# 39              DE       00450208239 1996-02-26
# 64              GB       08081570528 1992-12-02
# 100             GB       02079460690 1993-05-10
# 102             GB       01614960949 1995-08-23
# 127             GB       09098790520 1999-01-28
# ...            ...               ...        ...
# 15286           GB       01314960902 1994-08-21
# 15287           GB       01414960760 1999-04-03
# 15314           DE        0696627355 2000-06-28
# 10454           GB       01154960059 1994-09-18
# 12523           US  0015290026940260 2000-07-01
#
#                                   user_uuid
# index
# 39     15e92a28-e885-4844-9ead-17cb1a56fa6c
# 64     260f05c9-5b8a-4072-a7ac-edddb8e08907
# 100    ed003b7b-cc7c-4dab-960d-3e83bb99ee97
# 102    3971a10c-cd14-4ebe-acef-d2780239f6a3
# 127    ac10881b-86cb-42a7-820a-6f15ccbf456f
# ...                                     ...
# 15286  631d754e-dc6f-4861-9903-b4924199c0bb
# 15287  2f7eb4ca-3e98-4ee1-85bb-2bd4f99e4fe6
# 15314  e01045b8-cf88-4573-924c-7b1d44837162
# 10454  fe15cc78-a433-4bdc-9934-657cb8b24f9e
# 12523  cbfb7add-74d6-455f-926d-2fe6cc0d10c2
#
# [742 rows x 11 columns]>

# %%
users = users[users["join_date"] > users["date_of_birth"]]

# %%
users.to_string('filename.txt')

# %%
users.duplicated(['email_address']).sum()
# Out:
# 0

# %%
users.dtypes
# Out:
# first_name               string
# last_name                string
# date_of_birth    datetime64[ns]
# company                  string
# email_address            string
# address                  string
# country                category
# country_code           category
# phone_number             string
# join_date        datetime64[ns]
# user_uuid                string
# dtype: object

# %%
dim_card_details = DatabaseConnector.retrieve_pdf_data('https://data-handling-public.s3.eu-west-1.amazonaws.com/card_details.pdf')

# %%
dim_card_details = DataCleaning.clean_card_data(dim_card_details)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\steph\AppData\Local\Temp\ipykernel_10016\4185783719.py", line 1, in <module>
#     dim_card_details = DataCleaning.clean_card_data(dim_card_details)
# AttributeError: type object 'DataCleaning' has no attribute 'clean_card_data'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 1396, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 1287, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 1140, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 1055, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 955, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 778, in lines
#     return self._sd.lines
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\stack_data\core.py", line 677, in included_pieces
#     scope_pieces = self.scope_pieces
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\stack_data\core.py", line 614, in scope_pieces
#     scope_start, scope_end = self.source.line_range(self.scope)
#   File "C:\Users\steph\AppData\Roaming\Python\Python310\site-packages\stack_data\core.py", line 178, in line_range
#     return line_range(self.asttext(), node)
# AttributeError: 'Source' object has no attribute 'asttext'

# %%
len(dim_card_details)
# Out:
# 15284

# %%
type(dim_card_details)
# Out:
# pandas.core.frame.DataFrame

# %%
dim_card_details.dtypes
# Out:
# card_number               string
# expiry_date               object
# card_provider             string
# date_payment_confirmed    object
# dtype: object

# %%
dim_card_details = dim_card_details[dim_card_details['expiry_date'].str.len() == 5]

# %%
dim_card_details['card_number'] = dim_card_details['card_number'].astype('string')

# %%
dim_card_details['card_provider'] = dim_card_details['card_provider'].astype('string')

# %%
outliers = dim_card_details[dim_card_details['date_payment_confirmed'].str.len() < 10]
outliers
# Out:
# Empty DataFrame
# Columns: [card_number, expiry_date, card_provider, date_payment_confirmed]
# Index: []

# %%
def standardise_date(date):
    
    if len(date) == 10:
        return date
    
    months_dict = {'January':'01', 'February':'02', 'March':'03', 'April':'04', 
                   'May':'05', 'June':'06', 'July':'07', 'August':'08',
                   'September':'09', 'October':'10', 'November':'11', 'December':'12'}
    
    split_date = date.split(" ")
    day = split_date[-1]
    if split_date[0][0].isalpha():
        month = split_date[0]
        year = split_date[1]
    else:
        month = split_date[1]
        year = split_date[0]
    month = months_dict[month]
    # print(day)
    # print(month)
    # print(year)
    return f"{year}-{month}-{day}"

# %%
dim_card_details['date_payment_confirmed'] = dim_card_details['date_payment_confirmed'].apply(standardise_date)

# %%
dim_card_details['date_payment_confirmed'] = pd.to_datetime(dim_card_details['date_payment_confirmed'], format="%Y-%m-%d")
dim_card_details['date_payment_confirmed']
# Out:
# 0       2015-11-25
# 1       2001-06-18
# 2       2000-12-26
# 3       2011-02-12
# 4       1997-03-13
#            ...
# 15304   1997-06-06
# 15305   2004-06-16
# 15306   2020-02-05
# 15307   2008-06-16
# 15308   2009-02-04
# Name: date_payment_confirmed, Length: 15284, dtype: datetime64[ns]

# %%
dim_card_details['expiry_date']
# Out:
# 0        09/26
# 1        10/23
# 2        06/23
# 3        09/27
# 4        10/25
#          ...
# 15304    12/28
# 15305    11/24
# 15306    04/24
# 15307    06/27
# 15308    02/30
# Name: expiry_date, Length: 15284, dtype: object

# %%
dim_card_details['expiry_date'] = pd.to_datetime(dim_card_details['expiry_date'], format="%m/%y")

# %%
with open('api_key.yaml', 'r') as file:
    key_dict = yaml.load(file, Loader=yaml.FullLoader)

# %%
api_db = DataExtractor.retrieve_stores_data(f'https://aqj7u5id95.execute-api.eu-west-1.amazonaws.com/prod/store_details/', key_dict)

# %%
api_db
# Out:
#      index                                                     address  \
# 0        0                                                         N/A
# 1        1  Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, High Wycombe
# 2        2                 Heckerstraße 4/5\n50491 Säckingen, Landshut
# 3        3           5 Harrison tunnel\nSouth Lydia\nWC9 2BE, Westbury
# 4        4     Studio 6\nStephen landing\nSouth Simon\nB77 2WA, Belper
# ..     ...                                                         ...
# 446    446             Täschestraße 25\n39039 Nördlingen, Kirchlengern
# 447    447                                                  K0ODETRLS3
# 448    448      Studio 8\nMoss mall\nWest Linda\nM0E 6XR, High Wycombe
# 449    449                        Baumplatz 6\n80114 Kötzting, Bretten
# 450    450    Gotthilf-Rose-Straße 7/3\n45457 Feuchtwangen, Bad Honnef
#
#       longitude         lat      locality    store_code staff_numbers  \
# 0           N/A         N/A           N/A  WEB-1388012W           325
# 1      51.62907        None  High Wycombe   HI-9B97EE4E            34
# 2      48.52961        None      Landshut   LA-0772C7B9            92
# 3         51.26        None      Westbury   WE-1DE82CEE            69
# 4       53.0233        None        Belper   BE-18074576            35
# ..          ...         ...           ...           ...           ...
# 446        52.2        None  Kirchlengern   KI-78096E8C            61
# 447  K8CXLZDP07  UXMWDMX1LC    3VHFDNP8ET    9D4LK7X4LZ    D23PCWSM6S
# 448    51.62907        None  High Wycombe   HI-EEA7AE62            33
# 449    49.03685        None       Bretten   BR-662EC74C            35
# 450    50.64336        None    Bad Honnef   BA-B4AED588            36
#
#     opening_date   store_type    latitude country_code   continent
# 0     2010-06-12   Web Portal        None           GB      Europe
# 1     1996-10-25        Local    -0.74934           GB      Europe
# 2     2013-04-12  Super Store    12.16179           DE      Europe
# 3     2014-01-02  Super Store     -2.1875           GB      Europe
# 4     2019-09-09        Local    -1.48119           GB      Europe
# ..           ...          ...         ...          ...         ...
# 446   2005-05-12  Super Store     8.63333           DE      Europe
# 447   36IIMAQD58   NN04B3F6UQ  JZP8MIJTPZ   B3EH2ZGQAV  1WZB1TE1HL
# 448   1998-05-14        Local    -0.74934           GB      Europe
# 449   2020-10-17        Local     8.70745           DE      Europe
# 450   2001-05-12        Local      7.2278           DE    eeEurope
#
# [451 rows x 12 columns]

# %%
api_db = api_db.set_index('index')

# %%
api_db['country_code'] = api_db['country_code'].astype('category')
api_db['continent'] = api_db['continent'].astype('category')
api_db['store_type'] = api_db['store_type'].astype('category')
api_db['locality'] = api_db['locality'].astype('string')
api_db['store_code'] = api_db['store_code'].astype('string')
api_db = api_db.drop('lat', axis=1)

# %%
api_db['country_code'].value_counts()
# Out:
# GB            266
# DE            141
# US             34
# NULL            3
# B3EH2ZGQAV      1
# F3AO8V2LHU      1
# FP8DLXQVGH      1
# HMHIFNLOBN      1
# OH20I92LX3      1
# OYVW925ZL8      1
# YELVM536YT      1
# Name: country_code, dtype: int64

# %%
bad = api_db[api_db['country_code'].str.len() >=4]
bad
# Out:
#           address   longitude    locality  store_code staff_numbers  \
# index
# 63     6FWDZHD7PW  1ZVU03X2P6  9IBH8Y4Z0S  NRQKZWJ9OZ    BIP8K8JJW2
# 172    UBCIFQLSNY  Q1TJY8H1ZH  1T6B406CI8  QIUU9SVP51    SKBXAXF5G5
# 217          NULL        NULL        NULL        NULL          NULL
# 231    RC99UKMZB2  2YBZ1440V6  6LVWPU1G64  Y8J0Z2W8O9    2429OB3LMM
# 333    X349GIDWKU  O7NF1FZ74Y  RX9TCP2RGB  ISEE8A57FE    74BY7HSB6P
# 381    ZBGB54ID4H  SKO4NMRNNF  CQMHKI78BX  T0R2CQBDUS    GT1FO6YGD4
# 405          NULL        NULL        NULL        NULL          NULL
# 414    XTUAV57DP4  ID819KG3X5  RY6K0AUE7F  TUOKF5HAAQ    FRTGHAA34B
# 437          NULL        NULL        NULL        NULL          NULL
# 447    K0ODETRLS3  K8CXLZDP07  3VHFDNP8ET  9D4LK7X4LZ    D23PCWSM6S
#
#       opening_date  store_type    latitude country_code   continent
# index
# 63      ZCXWWKF45G  QP74AHEQT0  1CJ5OAU4BR   YELVM536YT  QMAVR5H3LD
# 172     7AHXLXIUEF  O0QJIRC943  3ZR3F89D97   FP8DLXQVGH  LU3E036ZD9
# 217           NULL        NULL        NULL         NULL        NULL
# 231     0OLAK2I6NS  50IB01SFAZ  L13EQEQODP   HMHIFNLOBN  5586JCLARW
# 333     A3PMVM800J  0RSNUU3DF5  J3BPB68Z1J   F3AO8V2LHU  GFJQ2AAEQ8
# 381     GMMB02LA9V  B4KVQB3P5Y  AJHOMDOHZ4   OH20I92LX3  SLQBD982C0
# 405           NULL        NULL        NULL         NULL        NULL
# 414     13PIY8GD1H  X0FE7E2EOG  AE7EEW4HSS   OYVW925ZL8  XQ953VS0FG
# 437           NULL        NULL        NULL         NULL        NULL
# 447     36IIMAQD58  NN04B3F6UQ  JZP8MIJTPZ   B3EH2ZGQAV  1WZB1TE1HL

# %%
api_db = api_db[api_db['country_code'].str.len() < 4]

# %%
api_db['continent'].value_counts()
# Out:
# Europe        383
# America        32
# eeEurope       24
# eeAmerica       2
# 1WZB1TE1HL      0
# 5586JCLARW      0
# GFJQ2AAEQ8      0
# LU3E036ZD9      0
# NULL            0
# QMAVR5H3LD      0
# SLQBD982C0      0
# XQ953VS0FG      0
# Name: continent, dtype: int64

# %%
def correct_continent(input):
    if len(input) <= 7:
        return input
    return input[2:]

# %%
api_db['continent'] = api_db['continent'].apply(correct_continent)

# %%
api_db['continent'] = api_db['continent'].astype('category')

# %%
bad = api_db[api_db['opening_date'].str.len() > 10]
bad
# Out:
#                                                                address  \
# index
# 10                   8 Gareth skyway\nSimmonsview\nSW4 7PL, Rutherglen
# 11                              Bergerstr. 1/3\n59183 Seelow, Siegburg
# 122                 Studio 66K\nChloe road\nStanleyberg\nS0 6NE, Selby
# 143              Eugenie-Pruschke-Straße 5\n31111 Badibling, Memmingen
# 190                      70 Ward center\nPort Nicola\nDT73 4WY, Bushey
# 242          Flat 84d\nCarol points\nPaigeland\nG3 0PD, Clacton-on-Sea
# 292                          Löwerallee 49\n00561 Miltenberg, Landshut
# 340              148 Samuel course\nNicolaside\nGY3E 5SD, Great Wyrley
# 369                   0 Marian circles\nPort Kayleigh\nPR5 6LW, Bushey
# 394    Studio 28Q\nElliott plains\nNorth Hollyfurt\nCT50 1XR, Aberdeen
#
#       longitude        locality   store_code staff_numbers      opening_date  \
# index
# 10     55.82885      Rutherglen  RU-9F1136B4            32   October 2012 08
# 11     50.80019        Siegburg  SI-ECD52CD9            25      July 2015 14
# 122    53.78333           Selby  SE-8DF6557B            20  2020 February 01
# 143    47.98372       Memmingen  ME-9940FF73             7       May 2003 27
# 190    51.64316          Bushey  BU-3FC2A064            25  2016 November 25
# 242    51.78967  Clacton-on-Sea  CL-DA786EF6            22   October 2006 04
# 292    48.52961        Landshut  LA-55069B69             6       2001 May 04
# 340    52.66277    Great Wyrley  GR-250FBD0C            27  1994 November 24
# 369    51.64316          Bushey  BU-B5B6F452            25  February 2009 28
# 394    57.14369        Aberdeen  AB-FCFAB1A9           106     March 2015 02
#
#         store_type  latitude country_code continent
# index
# 10           Local  -4.21376           GB    Europe
# 11           Local   7.20769           DE    Europe
# 122          Local  -1.06667           GB    Europe
# 143     Mall Kiosk  10.18527           DE    Europe
# 190          Local  -0.36053           GB    Europe
# 242          Local   1.15597           GB    Europe
# 292     Mall Kiosk  12.16179           DE    Europe
# 340          Local  -2.01111           GB    Europe
# 369          Local  -0.36053           GB    Europe
# 394    Super Store  -2.09814           GB    Europe

# %%
def standardise_date(date):
    
    if len(date) == 10:
        return date
    
    months_dict = {'January':'01', 'February':'02', 'March':'03', 'April':'04', 
                   'May':'05', 'June':'06', 'July':'07', 'August':'08',
                   'September':'09', 'October':'10', 'November':'11', 'December':'12'}
    
    split_date = date.split(" ")
    day = split_date[-1]
    if split_date[0][0].isalpha():
        month = split_date[0]
        year = split_date[1]
    else:
        month = split_date[1]
        year = split_date[0]
    month = months_dict[month]
    # print(day)
    # print(month)
    # print(year)
    return f"{year}-{month}-{day}"

# %%
api_db['opening_date'] = api_db['opening_date'].apply(standardise_date)

# %%
api_db['opening_date'] = pd.to_datetime(api_db['opening_date'], format="%Y-%m-%d")

# %%
def standardise_storenumbers(numb):
    
    numb = ''.join(c for c in numb if c.isdigit())
    return numb

# %%
api_db['staff_numbers'] = api_db['staff_numbers'].apply(standardise_storenumbers)

# %%
api_db['staff_numbers'] = api_db['staff_numbers'].astype('int64')

# %%
api_db
# Out:
#                                                           address longitude  \
# index
# 0                                                             N/A       N/A
# 1      Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, High Wycombe  51.62907
# 2                     Heckerstraße 4/5\n50491 Säckingen, Landshut  48.52961
# 3               5 Harrison tunnel\nSouth Lydia\nWC9 2BE, Westbury     51.26
# 4         Studio 6\nStephen landing\nSouth Simon\nB77 2WA, Belper   53.0233
# ...                                                           ...       ...
# 445            Flat 7\nStephanie lake\nMorrisside\nHP8 8LH, Cowes  50.76306
# 446               Täschestraße 25\n39039 Nördlingen, Kirchlengern      52.2
# 448        Studio 8\nMoss mall\nWest Linda\nM0E 6XR, High Wycombe  51.62907
# 449                          Baumplatz 6\n80114 Kötzting, Bretten  49.03685
# 450      Gotthilf-Rose-Straße 7/3\n45457 Feuchtwangen, Bad Honnef  50.64336
#
#            locality    store_code  staff_numbers opening_date   store_type  \
# index
# 0               N/A  WEB-1388012W            325   2010-06-12   Web Portal
# 1      High Wycombe   HI-9B97EE4E             34   1996-10-25        Local
# 2          Landshut   LA-0772C7B9             92   2013-04-12  Super Store
# 3          Westbury   WE-1DE82CEE             69   2014-01-02  Super Store
# 4            Belper   BE-18074576             35   2019-09-09        Local
# ...             ...           ...            ...          ...          ...
# 445           Cowes   CO-473A9FBB             94   2008-06-08  Super Store
# 446    Kirchlengern   KI-78096E8C             61   2005-05-12  Super Store
# 448    High Wycombe   HI-EEA7AE62             33   1998-05-14        Local
# 449         Bretten   BR-662EC74C             35   2020-10-17        Local
# 450      Bad Honnef   BA-B4AED588             36   2001-05-12        Local
#
#        latitude country_code continent
# index
# 0          None           GB    Europe
# 1      -0.74934           GB    Europe
# 2      12.16179           DE    Europe
# 3       -2.1875           GB    Europe
# 4      -1.48119           GB    Europe
# ...         ...          ...       ...
# 445    -1.29772           GB    Europe
# 446     8.63333           DE    Europe
# 448    -0.74934           GB    Europe
# 449     8.70745           DE    Europe
# 450      7.2278           DE    Europe
#
# [441 rows x 10 columns]

# %%
pd.set_option('display.max_colwidth', None)

# %%
api_db
# Out:
#                                                           address longitude  \
# index
# 0                                                             N/A       N/A
# 1      Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, High Wycombe  51.62907
# 2                     Heckerstraße 4/5\n50491 Säckingen, Landshut  48.52961
# 3               5 Harrison tunnel\nSouth Lydia\nWC9 2BE, Westbury     51.26
# 4         Studio 6\nStephen landing\nSouth Simon\nB77 2WA, Belper   53.0233
# ...                                                           ...       ...
# 445            Flat 7\nStephanie lake\nMorrisside\nHP8 8LH, Cowes  50.76306
# 446               Täschestraße 25\n39039 Nördlingen, Kirchlengern      52.2
# 448        Studio 8\nMoss mall\nWest Linda\nM0E 6XR, High Wycombe  51.62907
# 449                          Baumplatz 6\n80114 Kötzting, Bretten  49.03685
# 450      Gotthilf-Rose-Straße 7/3\n45457 Feuchtwangen, Bad Honnef  50.64336
#
#            locality    store_code  staff_numbers opening_date   store_type  \
# index
# 0               N/A  WEB-1388012W            325   2010-06-12   Web Portal
# 1      High Wycombe   HI-9B97EE4E             34   1996-10-25        Local
# 2          Landshut   LA-0772C7B9             92   2013-04-12  Super Store
# 3          Westbury   WE-1DE82CEE             69   2014-01-02  Super Store
# 4            Belper   BE-18074576             35   2019-09-09        Local
# ...             ...           ...            ...          ...          ...
# 445           Cowes   CO-473A9FBB             94   2008-06-08  Super Store
# 446    Kirchlengern   KI-78096E8C             61   2005-05-12  Super Store
# 448    High Wycombe   HI-EEA7AE62             33   1998-05-14        Local
# 449         Bretten   BR-662EC74C             35   2020-10-17        Local
# 450      Bad Honnef   BA-B4AED588             36   2001-05-12        Local
#
#        latitude country_code continent
# index
# 0          None           GB    Europe
# 1      -0.74934           GB    Europe
# 2      12.16179           DE    Europe
# 3       -2.1875           GB    Europe
# 4      -1.48119           GB    Europe
# ...         ...          ...       ...
# 445    -1.29772           GB    Europe
# 446     8.63333           DE    Europe
# 448    -0.74934           GB    Europe
# 449     8.70745           DE    Europe
# 450      7.2278           DE    Europe
#
# [441 rows x 10 columns]

# %%
def standardise_address(addr):
    if len(addr) == 3:
        return addr
    addr = re.split('\n|,', addr)
    addr = addr[:-1]
    addr = ', '.join(addr)
    return addr

# %%
api_db['address'] = api_db['address'].apply(standardise_address)

# %%
api_db['address']
# Out:
# index
# 0                                                  N/A
# 1         Flat 72W, Sally isle, East Deantown, E7B 8EB
# 2                    Heckerstraße 4/5, 50491 Säckingen
# 3              5 Harrison tunnel, South Lydia, WC9 2BE
# 4      Studio 6, Stephen landing, South Simon, B77 2WA
#                             ...
# 445        Flat 7, Stephanie lake, Morrisside, HP8 8LH
# 446                  Täschestraße 25, 39039 Nördlingen
# 448           Studio 8, Moss mall, West Linda, M0E 6XR
# 449                        Baumplatz 6, 80114 Kötzting
# 450       Gotthilf-Rose-Straße 7/3, 45457 Feuchtwangen
# Name: address, Length: 441, dtype: object

# %%
api_db = api_db.replace('N/A', np.NaN)

# %%
api_db.loc[0,['latitude']]=np.NaN

# %%
api_db
# Out:
#                                                address longitude  \
# index
# 0                                                  NaN       NaN
# 1         Flat 72W, Sally isle, East Deantown, E7B 8EB  51.62907
# 2                    Heckerstraße 4/5, 50491 Säckingen  48.52961
# 3              5 Harrison tunnel, South Lydia, WC9 2BE     51.26
# 4      Studio 6, Stephen landing, South Simon, B77 2WA   53.0233
# ...                                                ...       ...
# 445        Flat 7, Stephanie lake, Morrisside, HP8 8LH  50.76306
# 446                  Täschestraße 25, 39039 Nördlingen      52.2
# 448           Studio 8, Moss mall, West Linda, M0E 6XR  51.62907
# 449                        Baumplatz 6, 80114 Kötzting  49.03685
# 450       Gotthilf-Rose-Straße 7/3, 45457 Feuchtwangen  50.64336
#
#            locality    store_code  staff_numbers opening_date   store_type  \
# index
# 0              <NA>  WEB-1388012W            325   2010-06-12   Web Portal
# 1      High Wycombe   HI-9B97EE4E             34   1996-10-25        Local
# 2          Landshut   LA-0772C7B9             92   2013-04-12  Super Store
# 3          Westbury   WE-1DE82CEE             69   2014-01-02  Super Store
# 4            Belper   BE-18074576             35   2019-09-09        Local
# ...             ...           ...            ...          ...          ...
# 445           Cowes   CO-473A9FBB             94   2008-06-08  Super Store
# 446    Kirchlengern   KI-78096E8C             61   2005-05-12  Super Store
# 448    High Wycombe   HI-EEA7AE62             33   1998-05-14        Local
# 449         Bretten   BR-662EC74C             35   2020-10-17        Local
# 450      Bad Honnef   BA-B4AED588             36   2001-05-12        Local
#
#        latitude country_code continent
# index
# 0           NaN           GB    Europe
# 1      -0.74934           GB    Europe
# 2      12.16179           DE    Europe
# 3       -2.1875           GB    Europe
# 4      -1.48119           GB    Europe
# ...         ...          ...       ...
# 445    -1.29772           GB    Europe
# 446     8.63333           DE    Europe
# 448    -0.74934           GB    Europe
# 449     8.70745           DE    Europe
# 450      7.2278           DE    Europe
#
# [441 rows x 10 columns]

# %%
api_db['longitude']
# Out:
# index
# 0           NaN
# 1      51.62907
# 2      48.52961
# 3         51.26
# 4       53.0233
#          ...
# 445    50.76306
# 446        52.2
# 448    51.62907
# 449    49.03685
# 450    50.64336
# Name: longitude, Length: 441, dtype: object

# %%
api_db.dtypes
# Out:
# address                  object
# longitude                object
# locality                 string
# store_code               string
# staff_numbers             int64
# opening_date     datetime64[ns]
# store_type             category
# latitude                 object
# country_code           category
# continent              category
# dtype: object

# %%
def standardise_longitude(val):
    return round(float(val), 2) if val != 'NaN' else 'NaN'

# %%
api_db['longitude'] = api_db['longitude'].apply(standardise_longitude)

# %%
api_db['latitude'] = api_db['latitude'].apply(standardise_longitude)

# %%
api_db['latitude'].describe()
# Out:
# count    440.000000
# mean      -4.729159
# std       25.361253
# min     -122.390000
# 25%       -2.520000
# 50%       -0.750000
# 75%        8.467500
# max       13.320000
# Name: latitude, dtype: float64

# %%
api_db['address'] = api_db['address'].astype('string')

# %%
api_db
# Out:
#                                                address  longitude  \
# index
# 0                                                 <NA>        NaN
# 1         Flat 72W, Sally isle, East Deantown, E7B 8EB      51.63
# 2                    Heckerstraße 4/5, 50491 Säckingen      48.53
# 3              5 Harrison tunnel, South Lydia, WC9 2BE      51.26
# 4      Studio 6, Stephen landing, South Simon, B77 2WA      53.02
# ...                                                ...        ...
# 445        Flat 7, Stephanie lake, Morrisside, HP8 8LH      50.76
# 446                  Täschestraße 25, 39039 Nördlingen      52.20
# 448           Studio 8, Moss mall, West Linda, M0E 6XR      51.63
# 449                        Baumplatz 6, 80114 Kötzting      49.04
# 450       Gotthilf-Rose-Straße 7/3, 45457 Feuchtwangen      50.64
#
#            locality    store_code  staff_numbers opening_date   store_type  \
# index
# 0              <NA>  WEB-1388012W            325   2010-06-12   Web Portal
# 1      High Wycombe   HI-9B97EE4E             34   1996-10-25        Local
# 2          Landshut   LA-0772C7B9             92   2013-04-12  Super Store
# 3          Westbury   WE-1DE82CEE             69   2014-01-02  Super Store
# 4            Belper   BE-18074576             35   2019-09-09        Local
# ...             ...           ...            ...          ...          ...
# 445           Cowes   CO-473A9FBB             94   2008-06-08  Super Store
# 446    Kirchlengern   KI-78096E8C             61   2005-05-12  Super Store
# 448    High Wycombe   HI-EEA7AE62             33   1998-05-14        Local
# 449         Bretten   BR-662EC74C             35   2020-10-17        Local
# 450      Bad Honnef   BA-B4AED588             36   2001-05-12        Local
#
#        latitude country_code continent
# index
# 0           NaN           GB    Europe
# 1         -0.75           GB    Europe
# 2         12.16           DE    Europe
# 3         -2.19           GB    Europe
# 4         -1.48           GB    Europe
# ...         ...          ...       ...
# 445       -1.30           GB    Europe
# 446        8.63           DE    Europe
# 448       -0.75           GB    Europe
# 449        8.71           DE    Europe
# 450        7.23           DE    Europe
#
# [441 rows x 10 columns]

# %%
import boto3

s3 = boto3.client('s3')

# %%
s3.download_file('data-handling-public', 'products.csv', 's3_product_data.csv')

# %%
df = pd.read_csv('s3_product_data.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# product_name     object
# product_price    object
# weight           object
# category         object
# EAN              object
# date_added       object
# uuid             object
# removed          object
# product_code     object
# dtype: object

# %%
df
# Out:
#       Unnamed: 0                                 product_name product_price  \
# 0              0  FurReal Dazzlin' Dimples My Playful Dolphin        £39.99
# 1              1          Tiffany's World Day Out At The Park        £12.99
# 2              2          Tiffany's World Pups Picnic Playset         £7.00
# 3              3     Tiffany's World Wildlife Park Adventures        £12.99
# 4              4                      Cosatto Cosy Dolls Pram        £30.00
# ...          ...                                          ...           ...
# 1848        1848    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1849        1849    Goodmans Qi Wireless Charging Phone Stand        £15.00
# 1850        1850                     RAC 12V Wet & Dry Vacuum        £18.00
# 1851        1851    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1852        1852               Beldray Telescopic Ladder 2.9m        £69.00
#
#       weight        category            EAN  date_added  \
# 0      1.6kg  toys-and-games  7425710935115  2005-12-02
# 1     0.48kg  toys-and-games   487128731892  2006-01-09
# 2       590g  toys-and-games  1945816904649  1997-03-29
# 3       540g  toys-and-games  1569790890899  2013-03-20
# 4     1.91kg  toys-and-games  7142740213920  2007-12-23
# ...      ...             ...            ...         ...
# 1848    125g             diy  8185827751600  2020-08-28
# 1849    134g             diy  9769724533935  2012-05-20
# 1850    820g             diy  3113855860327  1993-11-28
# 1851    125g             diy  9195087467400  2016-09-20
# 1852   9.4kg             diy  8518402353072  2006-10-07
#
#                                       uuid          removed product_code
# 0     83dc0a69-f96f-4c34-bcb7-928acae19a94  Still_avaliable  R7-3126933h
# 1     712254d7-aea7-4310-aff8-8bcdd0aec7ff  Still_avaliable  C2-7287916l
# 2     b089ef6f-b628-4e37-811d-fffe0102ba64  Still_avaliable  S7-1175877v
# 3     d55de422-8b98-47d6-9991-e4bc4c5c0cb0          Removed  D8-8421505n
# 4     7945b657-cb02-4cc5-96cf-f65ed0a8f235  Still_avaliable  B6-2596063a
# ...                                    ...              ...          ...
# 1848  3ff21cb1-8e90-499d-b5a0-6839fb83e70f  Still_avaliable  x4-2227164k
# 1849  a7910f74-c2b6-4144-98b7-30ca68f34d2d  Still_avaliable  i3-8338545Z
# 1850  66d3efa0-f480-4da9-893b-e8aaff53e27b  Still_avaliable  n4-1642658b
# 1851  efb472f1-8f00-448e-a874-9fa9812eeab5  Still_avaliable  A3-7619070S
# 1852  cfe701da-6493-4a7f-83cf-9aab1650f689  Still_avaliable  i6-2851854w
#
# [1853 rows x 10 columns]

# %%
df = df[df['weight'].str.len() < 10]
df
# Out:
#       Unnamed: 0                                 product_name product_price  \
# 0              0  FurReal Dazzlin' Dimples My Playful Dolphin        £39.99
# 1              1          Tiffany's World Day Out At The Park        £12.99
# 2              2          Tiffany's World Pups Picnic Playset         £7.00
# 3              3     Tiffany's World Wildlife Park Adventures        £12.99
# 4              4                      Cosatto Cosy Dolls Pram        £30.00
# ...          ...                                          ...           ...
# 1848        1848    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1849        1849    Goodmans Qi Wireless Charging Phone Stand        £15.00
# 1850        1850                     RAC 12V Wet & Dry Vacuum        £18.00
# 1851        1851    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1852        1852               Beldray Telescopic Ladder 2.9m        £69.00
#
#       weight        category            EAN  date_added  \
# 0      1.6kg  toys-and-games  7425710935115  2005-12-02
# 1     0.48kg  toys-and-games   487128731892  2006-01-09
# 2       590g  toys-and-games  1945816904649  1997-03-29
# 3       540g  toys-and-games  1569790890899  2013-03-20
# 4     1.91kg  toys-and-games  7142740213920  2007-12-23
# ...      ...             ...            ...         ...
# 1848    125g             diy  8185827751600  2020-08-28
# 1849    134g             diy  9769724533935  2012-05-20
# 1850    820g             diy  3113855860327  1993-11-28
# 1851    125g             diy  9195087467400  2016-09-20
# 1852   9.4kg             diy  8518402353072  2006-10-07
#
#                                       uuid          removed product_code
# 0     83dc0a69-f96f-4c34-bcb7-928acae19a94  Still_avaliable  R7-3126933h
# 1     712254d7-aea7-4310-aff8-8bcdd0aec7ff  Still_avaliable  C2-7287916l
# 2     b089ef6f-b628-4e37-811d-fffe0102ba64  Still_avaliable  S7-1175877v
# 3     d55de422-8b98-47d6-9991-e4bc4c5c0cb0          Removed  D8-8421505n
# 4     7945b657-cb02-4cc5-96cf-f65ed0a8f235  Still_avaliable  B6-2596063a
# ...                                    ...              ...          ...
# 1848  3ff21cb1-8e90-499d-b5a0-6839fb83e70f  Still_avaliable  x4-2227164k
# 1849  a7910f74-c2b6-4144-98b7-30ca68f34d2d  Still_avaliable  i3-8338545Z
# 1850  66d3efa0-f480-4da9-893b-e8aaff53e27b  Still_avaliable  n4-1642658b
# 1851  efb472f1-8f00-448e-a874-9fa9812eeab5  Still_avaliable  A3-7619070S
# 1852  cfe701da-6493-4a7f-83cf-9aab1650f689  Still_avaliable  i6-2851854w
#
# [1846 rows x 10 columns]

# %%
def standardise_weight(weight):
    if weight == 'nan':
        return weight
    if 'kg' in weight:
        multiplier = 1
    elif 'k' not in weight:
        if 'oz' not in weight:
            multiplier = 1000
        else:
            multiplier = 35.274
    output = ''
    for letter in weight:
        if letter.isnumeric() or letter == '.':
            output += letter
        elif letter == 'x':
            multiplier = multiplier / float(output)
            output = ''
        elif letter.isalpha():
            return round(float(output)/multiplier, 3)

# %%
df['weight'] = df['weight'].apply(standardise_weight)
# Out:
# C:\Users\steph\AppData\Local\Temp\ipykernel_13968\1189199909.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['weight'] = df['weight'].apply(standardise_weight)

# %%
df
# Out:
#       Unnamed: 0                                 product_name product_price  \
# 0              0  FurReal Dazzlin' Dimples My Playful Dolphin        £39.99
# 1              1          Tiffany's World Day Out At The Park        £12.99
# 2              2          Tiffany's World Pups Picnic Playset         £7.00
# 3              3     Tiffany's World Wildlife Park Adventures        £12.99
# 4              4                      Cosatto Cosy Dolls Pram        £30.00
# ...          ...                                          ...           ...
# 1848        1848    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1849        1849    Goodmans Qi Wireless Charging Phone Stand        £15.00
# 1850        1850                     RAC 12V Wet & Dry Vacuum        £18.00
# 1851        1851    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1852        1852               Beldray Telescopic Ladder 2.9m        £69.00
#
#       weight        category            EAN  date_added  \
# 0      1.600  toys-and-games  7425710935115  2005-12-02
# 1      0.480  toys-and-games   487128731892  2006-01-09
# 2      0.590  toys-and-games  1945816904649  1997-03-29
# 3      0.540  toys-and-games  1569790890899  2013-03-20
# 4      1.910  toys-and-games  7142740213920  2007-12-23
# ...      ...             ...            ...         ...
# 1848   0.125             diy  8185827751600  2020-08-28
# 1849   0.134             diy  9769724533935  2012-05-20
# 1850   0.820             diy  3113855860327  1993-11-28
# 1851   0.125             diy  9195087467400  2016-09-20
# 1852   9.400             diy  8518402353072  2006-10-07
#
#                                       uuid          removed product_code
# 0     83dc0a69-f96f-4c34-bcb7-928acae19a94  Still_avaliable  R7-3126933h
# 1     712254d7-aea7-4310-aff8-8bcdd0aec7ff  Still_avaliable  C2-7287916l
# 2     b089ef6f-b628-4e37-811d-fffe0102ba64  Still_avaliable  S7-1175877v
# 3     d55de422-8b98-47d6-9991-e4bc4c5c0cb0          Removed  D8-8421505n
# 4     7945b657-cb02-4cc5-96cf-f65ed0a8f235  Still_avaliable  B6-2596063a
# ...                                    ...              ...          ...
# 1848  3ff21cb1-8e90-499d-b5a0-6839fb83e70f  Still_avaliable  x4-2227164k
# 1849  a7910f74-c2b6-4144-98b7-30ca68f34d2d  Still_avaliable  i3-8338545Z
# 1850  66d3efa0-f480-4da9-893b-e8aaff53e27b  Still_avaliable  n4-1642658b
# 1851  efb472f1-8f00-448e-a874-9fa9812eeab5  Still_avaliable  A3-7619070S
# 1852  cfe701da-6493-4a7f-83cf-9aab1650f689  Still_avaliable  i6-2851854w
#
# [1846 rows x 10 columns]

# %%
df.dtypes
# Out:
# product_name      object
# product_price    float64
# weight           float64
# category          object
# EAN               object
# date_added        object
# uuid              object
# removed           object
# product_code      object
# dtype: object

# %%
df.rename(columns = {'Unnamed: 0':'index'}, inplace = True)
# Out:
# C:\Users\steph\AppData\Local\Temp\ipykernel_13968\1294815572.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'Unnamed: 0':'index'}, inplace = True)

# %%
df = df.set_index('index')

# %%
df
# Out:
#                                       product_name product_price  weight  \
# index
# 0      FurReal Dazzlin' Dimples My Playful Dolphin        £39.99   1.600
# 1              Tiffany's World Day Out At The Park        £12.99   0.480
# 2              Tiffany's World Pups Picnic Playset         £7.00   0.590
# 3         Tiffany's World Wildlife Park Adventures        £12.99   0.540
# 4                          Cosatto Cosy Dolls Pram        £30.00   1.910
# ...                                            ...           ...     ...
# 1848     Goodmans Qi Autosense In Car Phone Holder        £15.00   0.125
# 1849     Goodmans Qi Wireless Charging Phone Stand        £15.00   0.134
# 1850                      RAC 12V Wet & Dry Vacuum        £18.00   0.820
# 1851     Goodmans Qi Autosense In Car Phone Holder        £15.00   0.125
# 1852                Beldray Telescopic Ladder 2.9m        £69.00   9.400
#
#              category            EAN  date_added  \
# index
# 0      toys-and-games  7425710935115  2005-12-02
# 1      toys-and-games   487128731892  2006-01-09
# 2      toys-and-games  1945816904649  1997-03-29
# 3      toys-and-games  1569790890899  2013-03-20
# 4      toys-and-games  7142740213920  2007-12-23
# ...               ...            ...         ...
# 1848              diy  8185827751600  2020-08-28
# 1849              diy  9769724533935  2012-05-20
# 1850              diy  3113855860327  1993-11-28
# 1851              diy  9195087467400  2016-09-20
# 1852              diy  8518402353072  2006-10-07
#
#                                        uuid          removed product_code
# index
# 0      83dc0a69-f96f-4c34-bcb7-928acae19a94  Still_avaliable  R7-3126933h
# 1      712254d7-aea7-4310-aff8-8bcdd0aec7ff  Still_avaliable  C2-7287916l
# 2      b089ef6f-b628-4e37-811d-fffe0102ba64  Still_avaliable  S7-1175877v
# 3      d55de422-8b98-47d6-9991-e4bc4c5c0cb0          Removed  D8-8421505n
# 4      7945b657-cb02-4cc5-96cf-f65ed0a8f235  Still_avaliable  B6-2596063a
# ...                                     ...              ...          ...
# 1848   3ff21cb1-8e90-499d-b5a0-6839fb83e70f  Still_avaliable  x4-2227164k
# 1849   a7910f74-c2b6-4144-98b7-30ca68f34d2d  Still_avaliable  i3-8338545Z
# 1850   66d3efa0-f480-4da9-893b-e8aaff53e27b  Still_avaliable  n4-1642658b
# 1851   efb472f1-8f00-448e-a874-9fa9812eeab5  Still_avaliable  A3-7619070S
# 1852   cfe701da-6493-4a7f-83cf-9aab1650f689  Still_avaliable  i6-2851854w
#
# [1846 rows x 9 columns]

# %%
df['product_price'] = df['product_price'].astype('string')

# %%
def standardise_prod_price(price):
    price = price[1:]
    return float(price)

# %%
df['product_price'] = df['product_price'].apply(standardise_prod_price)

# %%
df['product_price'] = df['product_price'].astype('float')

# %%
df['category'] = df['category'].astype('category')

# %%
df['EAN'] = df['EAN'].astype('string')

# %%
bad = df[df['date_added'].str.len() > 10]
bad
# Out:
#                                         product_name  product_price  weight  \
# index
# 307    Pets Pantry Complete Meaty Chunks Beef 2.75kg           3.69    2.75
# 1217                              Black Ceramic Vase           8.00    0.65
#
#        category            EAN         date_added  \
# index
# 307        pets  4525436759460    2018 October 22
# 1217   homeware  5806423927017  September 2017 06
#
#                                        uuid          removed product_code
# index
# 307    6fc67918-7940-4b1f-bba4-47f3e6dfc578  Still_avaliable  l1-2836416D
# 1217   38f124ff-1d42-4359-96f0-91490c9a6f26  Still_avaliable  M6-7203684r

# %%
def standardise_date(date):
    
    if len(date) == 10:
        return date
    
    months_dict = {'January':'01', 'February':'02', 'March':'03', 'April':'04', 
                   'May':'05', 'June':'06', 'July':'07', 'August':'08',
                   'September':'09', 'October':'10', 'November':'11', 'December':'12'}
    
    split_date = date.split(" ")
    day = split_date[-1]
    if split_date[0][0].isalpha():
        month = split_date[0]
        year = split_date[1]
    else:
        month = split_date[1]
        year = split_date[0]
    month = months_dict[month]
    # print(day)
    # print(month)
    # print(year)
    return f"{year}-{month}-{day}"

# %%
df['date_added'] = df['date_added'].apply(standardise_date)

# %%
df['date_added'] = pd.to_datetime(df['date_added'], format="%Y-%m-%d")

# %%
df['uuid'] = df['uuid'].astype('string')

# %%
df['removed'] = df['removed'].astype('category')
df['removed'].value_counts()
# Out:
# Still_avaliable    1752
# Removed              94
# Name: removed, dtype: int64

# %%
df['product_code'] = df['product_code'].astype('string')

# %%
df['product_name'] = df['product_name'].astype('string')

# %%
df.dtypes
# Out:
# product_name             string
# product_price           float64
# weight                  float64
# category               category
# EAN                      string
# date_added       datetime64[ns]
# uuid                     string
# removed                category
# product_code             string
# dtype: object

# %%
import yaml

# %%
db = DatabaseConnector() 
orders = DataExtractor.read_rds_table(db, 'orders_table')
# Out:
# ['legacy_store_details', 'legacy_users', 'orders_table']

# %%
orders = orders.set_index('index')
orders
# Out:
#         level_0                             date_uuid first_name last_name  \
# index
# 0             0  9476f17e-5d6a-4117-874d-9cdb38ca1fa6       None      None
# 1             1  0423a395-a04d-4e4a-bd0f-d237cbd5a295       None      None
# 2             2  65187294-bb16-4519-adc0-787bbe423970       None      None
# 3             3  579e21f7-13cb-436b-83ad-33687a4eb337       None      None
# 4             4  00ab86c3-2039-4674-b9c1-adbcbbf525bd       None      None
# ...         ...                                   ...        ...       ...
# 110548   110549  f0e8fff6-9998-4661-954b-0e258e09d33c       None      None
# 82164     82164  1c80940a-d186-4ba9-9daa-8abd1aceae32       None      None
# 97599     97599  58598aca-049c-418e-8e39-46327634a7f1     Sharon    Miller
# 106591   106591  3a76f661-0707-4fbc-9862-f21d3249f581       None      None
# 118804   118806  98fdc8b3-f619-4471-86b4-f44c26880166       None      None
#
#                                    user_uuid       card_number    store_code  \
# index
# 0       93caf182-e4e9-4c6e-bebb-60a1a9dcf9b8    30060773296197   BL-8387506C
# 1       8fe96c3a-d62d-4eb5-b313-cf12d9126a49   349624180933183  WEB-1388012W
# 2       fc461df4-b919-48b2-909e-55c95a03fe6b  3529023891650490   CH-01D85C8D
# 3       6104719f-ef14-4b09-bf04-fb0c4620acb0   213142929492281   CL-C183BE4B
# 4       9523a6d3-b2dd-4670-a51a-36aebc89f579      502067329974   SO-B5B9CB3B
# ...                                      ...               ...           ...
# 110548  95c74b0a-d495-4359-b1c0-e2da511e8403      575421945446   KA-FA7ED3B8
# 82164   5d6fa6fe-e583-4baf-8bbb-d1dd6e2b551f  4971858637664481   WA-A41DA979
# 97599   48b7f1fc-db13-4611-ad8e-3dac0b759488  4971858637664481  WEB-1388012W
# 106591  51c0b538-7ded-4697-8e84-9f7aa13f9112  4971858637664481   SO-6D328417
# 118804  e74907ca-1a4a-476c-a3ca-6b898b0964c2  4971858637664481   SO-6D328417
#
#        product_code   1  product_quantity
# index
# 0       R7-3126933h NaN                 3
# 1       C2-7287916l NaN                 2
# 2       S7-1175877v NaN                 2
# 3       D8-8421505n NaN                 2
# 4       B6-2596063a NaN                 2
# ...             ...  ..               ...
# 110548  C9-6827622o NaN                 4
# 82164   I0-1146408B NaN                 1
# 97599   A4-5443400b NaN                 4
# 106591  E9-2782979e NaN                 4
# 118804  m0-0281207X NaN                 3
#
# [120123 rows x 10 columns]

# %%
orders = orders.sort_index()

# %%
orders
# Out:
#         level_0                             date_uuid first_name last_name  \
# index
# 0             0  9476f17e-5d6a-4117-874d-9cdb38ca1fa6       None      None
# 1             1  0423a395-a04d-4e4a-bd0f-d237cbd5a295       None      None
# 2             2  65187294-bb16-4519-adc0-787bbe423970       None      None
# 3             3  579e21f7-13cb-436b-83ad-33687a4eb337       None      None
# 4             4  00ab86c3-2039-4674-b9c1-adbcbbf525bd       None      None
# ...         ...                                   ...        ...       ...
# 120118   120118  c2131886-7dc4-4812-af30-2182b3dcab68       None      None
# 120119   120119  eca2b196-ec12-4853-b3d5-41e029d14774       None      None
# 120120   120120  c0b61063-d282-423f-84e3-81371263c980       None      None
# 120121   120121  80867068-2c01-4a14-a6c5-f7ad0764fbd2       None      None
# 120122   120122  fe3f9a13-b862-4395-84eb-ead9de40c3d6       None      None
#
#                                    user_uuid       card_number    store_code  \
# index
# 0       93caf182-e4e9-4c6e-bebb-60a1a9dcf9b8    30060773296197   BL-8387506C
# 1       8fe96c3a-d62d-4eb5-b313-cf12d9126a49   349624180933183  WEB-1388012W
# 2       fc461df4-b919-48b2-909e-55c95a03fe6b  3529023891650490   CH-01D85C8D
# 3       6104719f-ef14-4b09-bf04-fb0c4620acb0   213142929492281   CL-C183BE4B
# 4       9523a6d3-b2dd-4670-a51a-36aebc89f579      502067329974   SO-B5B9CB3B
# ...                                      ...               ...           ...
# 120118  f58cc2aa-e4b7-4893-a1e3-734c7e45c94e  2291071373356040   HI-F27C7A84
# 120119  2c4a5960-a6b1-4743-a74f-27c177d67b55  3599396269535600   DA-ACC520AE
# 120120  44064842-6dbe-4c8d-8bb0-839df7d75d62  3562219981147900   TR-8CD56339
# 120121  1e231760-b8b3-4754-a377-e7e1663dc263  3539896505196310  WEB-1388012W
# 120122  60021fcd-f0c2-4522-914b-2f8ee18a7d89      676112613481   ST-8D1A43F1
#
#        product_code   1  product_quantity
# index
# 0       R7-3126933h NaN                 3
# 1       C2-7287916l NaN                 2
# 2       S7-1175877v NaN                 2
# 3       D8-8421505n NaN                 2
# 4       B6-2596063a NaN                 2
# ...             ...  ..               ...
# 120118  w5-6777421C NaN                 4
# 120119  z2-7184027O NaN                 3
# 120120   m4-507493i NaN                 4
# 120121  x0-8613539X NaN                14
# 120122   i7-488835x NaN                 6
#
# [120123 rows x 10 columns]

# %%
orders = orders.drop(['level_0', 'first_name', 'last_name', '1'], axis = 1)

# %%
orders['date_uuid'] = orders['date_uuid'].astype('string')
orders['user_uuid'] = orders['user_uuid'].astype('string')
orders['store_code'] = orders['store_code'].astype('string')
orders['product_code'] = orders['product_code'].astype('string')

# %%
orders['card_number'] = orders['card_number'].astype('string')

# %%
link = 'https://data-handling-public.s3.eu-west-1.amazonaws.com/date_details.json'

# %%
events = pd.read_json(link)
events
# Out:
#        timestamp month  year day time_period  \
# 0       22:00:06     9  2012  19     Evening
# 1       22:44:06     2  1997  10     Evening
# 2       10:05:37     4  1994  15     Morning
# 3       17:29:27    11  2001   6      Midday
# 4       22:40:33    12  2015  31     Evening
# ...          ...   ...   ...  ..         ...
# 120156  22:56:56    11  2022  12     Evening
# 120157  18:25:20     5  1997  31     Evening
# 120158  18:21:40     9  2011  13     Evening
# 120159  19:10:53     7  2013  12     Evening
# 120160  21:17:12     3  2008  18     Evening
#
#                                    date_uuid
# 0       3b7ca996-37f9-433f-b6d0-ce8391b615ad
# 1       adc86836-6c35-49ca-bb0d-65b6507a00fa
# 2       5ff791bf-d8e0-4f86-8ceb-c7b60bef9b31
# 3       1b01fcef-5ab9-404c-b0d4-1e75a0bd19d8
# 4       dfa907c1-f6c5-40f0-aa0d-40ed77ac5a44
# ...                                      ...
# 120156  d6c4fb31-720d-4e94-aa6b-dcbcb85f2bb7
# 120157  f7722027-1aae-49c3-8f8d-853e93f9f3e6
# 120158  4a3b9851-52e1-463c-ac81-1960f141444e
# 120159  64974909-0d4b-42a2-822a-73b5695e8bfb
# 120160  55c228c7-14ee-4d46-99a9-01dfc57d1adf
#
# [120161 rows x 6 columns]

# %%
events = events[events['day'].str.len() <= 2]
events
# Out:
#        timestamp month  year day time_period  \
# 0       22:00:06     9  2012  19     Evening
# 1       22:44:06     2  1997  10     Evening
# 2       10:05:37     4  1994  15     Morning
# 3       17:29:27    11  2001   6      Midday
# 4       22:40:33    12  2015  31     Evening
# ...          ...   ...   ...  ..         ...
# 120156  22:56:56    11  2022  12     Evening
# 120157  18:25:20     5  1997  31     Evening
# 120158  18:21:40     9  2011  13     Evening
# 120159  19:10:53     7  2013  12     Evening
# 120160  21:17:12     3  2008  18     Evening
#
#                                    date_uuid
# 0       3b7ca996-37f9-433f-b6d0-ce8391b615ad
# 1       adc86836-6c35-49ca-bb0d-65b6507a00fa
# 2       5ff791bf-d8e0-4f86-8ceb-c7b60bef9b31
# 3       1b01fcef-5ab9-404c-b0d4-1e75a0bd19d8
# 4       dfa907c1-f6c5-40f0-aa0d-40ed77ac5a44
# ...                                      ...
# 120156  d6c4fb31-720d-4e94-aa6b-dcbcb85f2bb7
# 120157  f7722027-1aae-49c3-8f8d-853e93f9f3e6
# 120158  4a3b9851-52e1-463c-ac81-1960f141444e
# 120159  64974909-0d4b-42a2-822a-73b5695e8bfb
# 120160  55c228c7-14ee-4d46-99a9-01dfc57d1adf
#
# [120123 rows x 6 columns]

# %%
events['date_uuid'] = events['date_uuid'].astype('string')
events['time_period'] = events['time_period'].astype('category')
events['year'] = events['year'].astype('string')
events['month'] = events['month'].astype('string')
events['day'] = events['day'].astype('string')

# %%
events.dtypes
# Out:
# timestamp        object
# month            string
# year             string
# day              string
# time_period    category
# date_uuid        string
# dtype: object

# %%
#events['timestamp'] = pd.to_datetime(events['timestamp'], format='%H:%M:%S').dt.time
# Out:
# C:\Users\steph\AppData\Local\Temp\ipykernel_19988\1665738356.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   events['timestamp'] = pd.to_datetime(events['timestamp'], format='%H:%M:%S').dt.time

# %%
def pad_day_month(day):
    if len(day) == 2:
        return day
    else: return '0' + day
events['day'] = events['day'].apply(pad_day_month)
events['month'] = events['month'].apply(pad_day_month)

# %%
events['date'] = events[['year', 'month', 'day']].agg('-'.join, axis=1)

# %%
events['iso'] = events[['date', 'timestamp']].agg(' '.join, axis=1)

# %%
events
# Out:
#        timestamp month  year day time_period  \
# 0       22:00:06    09  2012  19     Evening
# 1       22:44:06    02  1997  10     Evening
# 2       10:05:37    04  1994  15     Morning
# 3       17:29:27    11  2001  06      Midday
# 4       22:40:33    12  2015  31     Evening
# ...          ...   ...   ...  ..         ...
# 120156  22:56:56    11  2022  12     Evening
# 120157  18:25:20    05  1997  31     Evening
# 120158  18:21:40    09  2011  13     Evening
# 120159  19:10:53    07  2013  12     Evening
# 120160  21:17:12    03  2008  18     Evening
#
#                                    date_uuid        date                  iso
# 0       3b7ca996-37f9-433f-b6d0-ce8391b615ad  2012-09-19  2012-09-19 22:00:06
# 1       adc86836-6c35-49ca-bb0d-65b6507a00fa  1997-02-10  1997-02-10 22:44:06
# 2       5ff791bf-d8e0-4f86-8ceb-c7b60bef9b31  1994-04-15  1994-04-15 10:05:37
# 3       1b01fcef-5ab9-404c-b0d4-1e75a0bd19d8  2001-11-06  2001-11-06 17:29:27
# 4       dfa907c1-f6c5-40f0-aa0d-40ed77ac5a44  2015-12-31  2015-12-31 22:40:33
# ...                                      ...         ...                  ...
# 120156  d6c4fb31-720d-4e94-aa6b-dcbcb85f2bb7  2022-11-12  2022-11-12 22:56:56
# 120157  f7722027-1aae-49c3-8f8d-853e93f9f3e6  1997-05-31  1997-05-31 18:25:20
# 120158  4a3b9851-52e1-463c-ac81-1960f141444e  2011-09-13  2011-09-13 18:21:40
# 120159  64974909-0d4b-42a2-822a-73b5695e8bfb  2013-07-12  2013-07-12 19:10:53
# 120160  55c228c7-14ee-4d46-99a9-01dfc57d1adf  2008-03-18  2008-03-18 21:17:12
#
# [120123 rows x 8 columns]

# %%
events['iso'] = pd.to_datetime(events['iso'])

# %%
events = events.drop(['date'], axis=1)

# %%
events.dtypes
# Out:
# timestamp              object
# month                  object
# year                   string
# day                    object
# time_period          category
# date_uuid              string
# iso            datetime64[ns]
# dtype: object
